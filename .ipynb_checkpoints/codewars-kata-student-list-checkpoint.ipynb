# %%
# Imports

import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup

from adquire_functions import get_students_and_katas
from cleaning_funcions import clean_katas
from chosing_functions import display_presenter_last_kata

# %%
def adquire(): 
    return get_students_and_katas()

def cleaning(df_students, df_katas): 
    return df_students, clean_katas(df_katas)

# %%
def get_completed_by_user(user, host='https://www.codewars.com/api/v1/users/', 
                          path='/code-challenges/completed'):
    url = host + user + path
    resp = requests.get(url)
    
    return resp.json()

def user_time_kata(user, slug, completed, katas): 
    res = '2090-01-01T00:00:00.000Z'# default
    for data in completed[user]: 
        if data['slug'] == slug: 
            res = data['completedAt']
            break
    return res

def get_info_dict(df_students): 
    completed = {u: get_completed_by_user(u) for u in df_students.index}    
    res_dict = dict( [(k, v['data']) for k, v in completed.items()] )
    return res_dict

def create_df_checking(df_students, df_katas): 
    katas = df_katas.index
    students = df_students.index
    
    # Creamos un DataFrame: Students x Katas
    df_res = pd.DataFrame(index=df_students.index, columns=df_katas.index)
    
    # tarda un rato
    completed_katas_dict = get_info_dict(df_students)
       
    # cada celda es el tiempo que ese student(row) tardó en realizar la kata(column)
    for user in students: 
        for slug in katas: 
            df_res.loc[user, slug] = user_time_kata(user, slug, completed_katas_dict, katas)
    
    # convertimos las columnas a tipo Datetime
    for col in df_res.columns: 
        df_res[col] = pd.to_datetime(df_res[col],infer_datetime_format=True)
        
    # En este punto df_res son valores temporales    
    # copiamos la solución en otro DF porque en el bucle la segunda vez da problemas al cambiar el tipo
    df_sol = df_res.copy()

    # display(df_res)
    for user in students: 
        df_sol.loc[user] = df_res.loc[user] < df_katas.limit
    
    return df_sol

# %%
def save_results(df, path='results.csv'): 
    df.to_csv(path, index=True)

# %%
def main(): 
    df_students, df_katas = adquire()
    df_students, df_katas = cleaning(df_students, df_katas)
    
    df = create_df_checking(df_students, df_katas)
    
    display(df)    
    save_results(df)
    print( display_presenter_last_kata(df) )

# %%
if __name__ == '__main__':
    main()
# Out:
# slug            regexp-fun-number-1-when-i-miss-few-days-of-gym  \
# username
# paulapr                                                    True
# Almugs                                                    False
# hector-moreno                                              True
# potacho                                                    True
# carlosmd14                                                 True
# Livia Canet                                                True
# AlejandroFrank                                             True
# AlejandroPerela                                            True
# leyremarazuela                                            False
# LauraRepullo                                              False
# pecatade                                                   True
# NicoST1                                                    True
# lmartinezruizit                                            True
# RodMech                                                    True
#
# slug            deodorant-evaporator ordered-count-of-characters  \
# username
# paulapr                         True                        True
# Almugs                          True                        True
# hector-moreno                   True                        True
# potacho                         True                       False
# carlosmd14                      True                        True
# Livia Canet                     True                       False
# AlejandroFrank                 False                        True
# AlejandroPerela                 True                        True
# leyremarazuela                 False                       False
# LauraRepullo                   False                        True
# pecatade                        True                        True
# NicoST1                         True                        True
# lmartinezruizit                 True                        True
# RodMech                         True                        True
#
# slug            reverse-or-rotate the-deaf-rats-of-hamelin read-the-time  \
# username
# paulapr                     False                    False          True
# Almugs                      False                     True          True
# hector-moreno               False                     True          True
# potacho                     False                     True         False
# carlosmd14                   True                     True          True
# Livia Canet                 False                    False         False
# AlejandroFrank              False                     True         False
# AlejandroPerela             False                     True          True
# leyremarazuela              False                     True         False
# LauraRepullo                False                    False         False
# pecatade                     True                     True          True
# NicoST1                     False                    False          True
# lmartinezruizit              True                     True          True
# RodMech                      True                     True          True
#
# slug            scraping-get-the-year-a-codewarrior-joined  \
# username
# paulapr                                               True
# Almugs                                               False
# hector-moreno                                         True
# potacho                                              False
# carlosmd14                                            True
# Livia Canet                                          False
# AlejandroFrank                                        True
# AlejandroPerela                                       True
# leyremarazuela                                        True
# LauraRepullo                                         False
# pecatade                                              True
# NicoST1                                               True
# lmartinezruizit                                       True
# RodMech                                               True
#
# slug            user-class-for-banking-system moving-average  \
# username
# paulapr                                  True          False
# Almugs                                   True          False
# hector-moreno                            True           True
# potacho                                 False           True
# carlosmd14                               True           True
# Livia Canet                              True           True
# AlejandroFrank                           True           True
# AlejandroPerela                          True           True
# leyremarazuela                           True          False
# LauraRepullo                            False          False
# pecatade                                 True           True
# NicoST1                                  True           True
# lmartinezruizit                          True           True
# RodMech                                  True           True
#
# slug            replace-with-alphabet-position directions-reduction
# username
# paulapr                                   True                False
# Almugs                                    True                False
# hector-moreno                             True                 True
# potacho                                  False                False
# carlosmd14                                True                 True
# Livia Canet                               True                 True
# AlejandroFrank                            True                False
# AlejandroPerela                           True                False
# leyremarazuela                            True                 True
# LauraRepullo                              True                False
# pecatade                                  True                False
# NicoST1                                   True                False
# lmartinezruizit                           True                 True
# RodMech                                   True                False
# leyremarazuela presentará la kata directions-reduction
