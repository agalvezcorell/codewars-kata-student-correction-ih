# %%
# Imports

import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup

from modules.adquire_functions import get_students_and_katas
from modules.cleaning_funcions import clean_katas
from modules.chosing_functions import display_presenter_last_kata


# functions
def adquire(): 
    return get_students_and_katas()

def cleaning(df_students, df_katas): 
    return df_students, clean_katas(df_katas)

def get_completed_by_user(user, host='https://www.codewars.com/api/v1/users/', 
                          path='/code-challenges/completed'):
    url = host + user + path
    resp = requests.get(url)    
    return resp.json()

def user_time_kata(user, slug, completed, katas): 
    res = '2090-01-01T00:00:00.000Z'# default
    for data in completed[user]: 
        if data['slug'] == slug: 
            res = data['completedAt']
            break
    return res

def get_info_dict(df_students): 
    completed = {u: get_completed_by_user(u) for u in df_students.index}    
    
    res_dict = dict( [(k, v['data']) for k, v in completed.items()] )
    return res_dict

def create_df_checking(df_students, df_katas): 
    katas = df_katas.index
    students = df_students.index
    
    # Creamos un DataFrame: Students x Katas
    df_res = pd.DataFrame(index=df_students.index, columns=df_katas.index)
        
    # tarda un rato
    completed_katas_dict = get_info_dict(df_students)
       
    # cada celda es el tiempo que ese student(row) tardó en realizar la kata(column)
    for user in students: 
        for slug in katas: 
            df_res.loc[user, slug] = user_time_kata(user, slug, completed_katas_dict, katas)
    
    # convertimos las columnas a tipo Datetime
    for col in df_res.columns: 
        df_res[col] = pd.to_datetime(df_res[col],infer_datetime_format=True)
        
    # En este punto df_res son valores temporales    
    # copiamos la solución en otro DF porque en el bucle la segunda vez da problemas al cambiar el tipo
    df_sol = df_res.copy()

    # display(df_res)
    for user in students: 
        df_sol.loc[user] = df_res.loc[user] < df_katas.limit
    
    return df_sol

def save_results(df, folder='./output/'): 
    df.to_csv(folder + 'output.csv', index=True) 
    
    writer = pd.ExcelWriter(folder + 'output.xlsx')
    df.to_excel(writer, 'Sheet1')
    # df2.to_excel(writer,'Sheet2')
    writer.save()
    
def color_negative_red(x):
    """
    Takes a boolean and returns a string with
    the css property `'color: red'` for False
    strings, green otherwise.
    """
    color = 'red' if x == False else 'green'
    return 'color: {}'.format(color) 

def display_with_colors(df): 
    df_style = df.style.applymap(color_negative_red)
    display(df_style)

def outputs(df): 
    display_presenter_last_kata(df)       
    display_with_colors(df)   
    save_results(df)

# %%
# Main    
    
def main(): 
    df_students, df_katas = adquire()    
    df_students, df_katas = cleaning(df_students, df_katas)    
    df = create_df_checking(df_students, df_katas)    
    outputs(df)


if __name__ == '__main__':
    main()
# Out:
# Alejandra Aranzadi presentará la kata 80-s-kids-number-2-help-alf-find-his-spaceship
# <style  type="text/css" >
#     #T_922ddd44_934f_11e9_af42_5c514fd29402row0_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row0_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row1_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row1_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row2_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row2_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row3_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row3_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row4_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row4_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row5_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row5_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row6_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row6_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row7_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row7_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row8_col0 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row8_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row9_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row9_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row10_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row10_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row11_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row11_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row12_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row12_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row13_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row13_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row14_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row14_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row15_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row15_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row16_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row16_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row17_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row17_col1 {
#             color:  red;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row18_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row18_col1 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row19_col0 {
#             color:  green;
#         }    #T_922ddd44_934f_11e9_af42_5c514fd29402row19_col1 {
#             color:  red;
#         }</style><table id="T_922ddd44_934f_11e9_af42_5c514fd29402" ><thead>    <tr>        <th class="index_name level0" >slug</th>        <th class="col_heading level0 col0" >sql-with-sailor-moon-thinking-about-joins-dot-dot-dot</th>        <th class="col_heading level0 col1" >80-s-kids-number-2-help-alf-find-his-spaceship</th>    </tr>    <tr>        <th class="index_name level0" >username</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row0" class="row_heading level0 row0" >lgarciaco1</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row0_col0" class="data row0 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row0_col1" class="data row0 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row1" class="row_heading level0 row1" >deliaclar</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row1_col0" class="data row1 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row1_col1" class="data row1 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row2" class="row_heading level0 row2" >Pela12345</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row2_col0" class="data row2 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row2_col1" class="data row2 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row3" class="row_heading level0 row3" >Pacoanes</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row3_col0" class="data row3 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row3_col1" class="data row3 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row4" class="row_heading level0 row4" >Alejandra Aranzadi</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row4_col0" class="data row4 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row4_col1" class="data row4 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row5" class="row_heading level0 row5" >Mgraciaverdura</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row5_col0" class="data row5 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row6" class="row_heading level0 row6" >fserrey</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row6_col0" class="data row6 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row7" class="row_heading level0 row7" >maxsanchezdp</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row7_col0" class="data row7 col0" >True</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row7_col1" class="data row7 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row8" class="row_heading level0 row8" >emachadoc</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row8_col0" class="data row8 col0" >False</td>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_922ddd44_934f_11e9_af42_5c514fd29402level0_row9" class="row_heading level0 row9" >fonsiman</th>
#                         <td id="T_922ddd44_934f_11e9_af42_5c514fd29402row9_col0" class="data row9 col0" >True</td>
